# %%
# Magic commands to pull in all your modular DLT notebooks
# Inside: src/dlt_master_orchestrator

# --- BRONZE LAYER EXTRACTIONS ---
# For DLT to compile these correctly, make sure the paths are exact relative to this file!
# %run /Workspace/Users/ssangat@robling.io/retaail_analysis/src/bronze/dlt_extract_sales
# %run /Workspace/Users/ssangat@robling.io/retaail_analysis/src/bronze/dlt_extract_location
# --- SILVER LAYER CLEANING ---
# %run /Workspace/Users/ssangat@robling.io/retaail_analysis/src/silver/dlt_clean_sales
# %run /Workspace/Users/ssangat@robling.io/retaail_analysis/src/silver/dlt_clean_location

# --- GOLD LAYER AGGREGATIONS ---
# %run /Workspace/Users/ssangat@robling.io/retaail_analysis/src/gold/dlt_sales_by_location
